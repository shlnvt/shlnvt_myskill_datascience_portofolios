# %% [markdown]
# <a href="https://colab.research.google.com/github/shlnvt/shlnvt_myskill_datascience_portofolios/blob/main/Data_Visualization_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Library

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #Load data

# %%
dataset = sns.load_dataset("mpg")

# %%
dataset.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# #Membuat pie chart

# %% [markdown]
# ##Mempersiapkan data untuk plot

# %%
data_origin = dataset["origin"].value_counts().to_dict()

data_pie = data_origin.values()
label_pie = data_origin.keys()
colors = sns.color_palette('pastel')[0:5]

# %% [markdown]
# ##Pie chart

# %%
plt.pie(x=data_pie,
        labels = label_pie,
        colors = colors,
        autopct='%.0f%%'
)
plt.title("Origin")
plt.show()

# %% [markdown]
# #Membuat histogram

# %%
sns.histplot(data = dataset,
            x = "mpg",
            bins = 30)
plt.show()

# %% [markdown]
# #Membuat boxplot

# %%
sns.boxplot(data = dataset,
            x = "mpg")
plt.show()

# %% [markdown]
# #Membuat bar chart

# %%
sns.barplot(data = dataset,
            x = "origin",
            y = "mpg",
            )
plt.show()

# %% [markdown]
# #Membuat lineplot

# %%
sns.lineplot(data = dataset,
             x = "model_year",
             y = "mpg",
             hue = "origin")
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %% [markdown]
# #Membuat scatterplot

# %%
sns.scatterplot(data = dataset,
                x = "displacement",
                y = "mpg")
# Out:
# <Axes: xlabel='displacement', ylabel='mpg'>
